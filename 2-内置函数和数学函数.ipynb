# %% [markdown]
# ***<font color=FF0000> Examples: 内置函数、数学函数库的使用 </font>***

# %% [markdown]
# **<font color=#0080FF> 内置函数：print(表达式, ......) </font>**
# + (从左自右逐个) 求值实参表达式，并在执行窗口 (shell) 中输出
# +  默认情况下，每两项输出之间用 <font color=yellow>空格</font> 分隔
# +  默认情况下，输出所有实参值之后，自动<font color=yellow>换一行</font>
# + print 函数的更多使用细节之后介绍，也可自行查阅语言手册

# %%
print(123)
# Out:
# 123

# %%
print(123, 1.23)   # 默认情况下，用 空格 分隔多个输出对象

## Python 程序里的一行里，从井号 # 开始到该行末尾都是注释
## 注释是说明性文字，供人阅读
## 执行时，解释器将跳过所有注释 (没有任何语义)
# Out:
# 123 1.23

# %%
print(1/17) ## 调用函数 print 时，可以用任意合适的表达式作为实参
# Out:
# 0.058823529411764705

# %% [markdown]
# **<font color=#0080FF>print 输出浮点数时，可指定保留小数点后有效数字的位数 ——</font> <font color=yellow>格式化输出</font>**
# + 下面先介绍一种简单、但有点过时的处理方式 (https://docs.python.org/zh-cn/3.8/library/stdtypes.html#printf-style-string-formatting)
# + 还有其它的格式化方式 (例如 f-string, str.format 方法)，之后逐步介绍，也可自行查阅语言手册

# %%
print('%.6f' % (1/17))  ## 输出时，保留小数点后 6 位有效数字

# 注意：(1/17) 的写法
# Out:
# 0.058824

# %%
print('%f'%0.5)    

## %f，被称为模板字符串，表示：要输出一个浮点数，并且保留小数点后 6 位有效数字 
## (沿袭了 C 语言中 printf 的风格)
# Out:
# 0.500000

# %%
print('%.1f' % 1.15)  ## Note：属于 "非精确的四舍五入规则"
print('%.1f' % 1.85)
# Out:
# 1.1
# 1.9

# %% [markdown]
# <p></p>
#
# **<font color=#0080FF>输出整数时，也有相应的格式化方式</font>**
# + 下面只作初步介绍；更详细情况之后介绍，也可自行查阅语言手册

# %%
## %d，表示要输出一个整数
print('%d' % 123)

# %%
## %10d，在输出一个整数可指定最小输出宽度；整数不够宽时，默认居右输出，高位补空格
print('%10d' % 456)
# Out:
#        456

# %%
## 一次输出多个数值对象，并指定输出格式
print('%d'%123, '%.6f'%.123)

print('%d %.6f' % (123, .123))

## 上述两种写法等价

# %% [markdown]
# <p></p>
#
# **<font color=#0080FF> 内置函数：abs(x) </font>**
# + Return the absolute value of a number.
# + The argument may be an integer or a floating point number.
# + If the argument is a complex number, its magnitude is returned.

# %%
abs(-389)
# Out:
# 389

# %%
abs(-2.3**5)
# Out:
# 64.36342999999998

# %%
abs((2+3.5j)**4)

# %% [markdown]
# <p></p>
#
# **<font color=#0080FF> 内置函数：max(arg1, arg2, \*args[, key]) </font>**
# + Return the largest of two or more arguments.
#
# **<font color=#0080FF> 内置函数：min(arg1, arg2, \*args[, key])  </font>**
# + Return the smallest of two or more arguments.

# %%
max(2, 4.3, -1.23, 8.6)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
round(1.27)
# Out:
# 1

# %%
round(1.27**6, 4)
# Out:
# 4.1959

# %%
round(1.2000, 3)  ## 使用 round 时存在一些坑，应谨慎使用
# Out:
# 1.2

# %%
round(1.000, 2)
# Out:
# 1.0

# %% [markdown]
# <p></p>
#
# _**<font color=#0080FF>NOTE</font>：更精确的舍入操作，建议使用标准库 decimal 模块中有关函数，详情请查阅语言手册**_

# %% [markdown]
# <p></p>
#
# **<font color=#0080FF>内置函数：pow(base, exp[, mod]) </font>**
# + Return base to the power exp; if mod is present, return base to the power exp, modulo mod (computed more efficiently than pow(base, exp) % mod).
# + The two-argument form pow(base, exp) is equivalent to using the power operator: base**exp.

# %%
pow(2.3, 1.5)

# %%
pow(3, 3, 2)

# %%
pow(1.5, 2.78, 2.4)

# %% [markdown]
# <p></p>
#
# **<font color=#0080FF>数学函数库：The 'math' module provides access to the mathematical functions defined by the C standard </font>**
# + These functions cannot be used with complex numbers.

# %%
import math  ## 使用 import 语句导入 math 包

# %%
dir(math)    ## 内置函数 dir
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
help(math)   ## 内置函数 help
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
math.sin(math.pi)

## NOTE：不同形式的导入语句对应不同的使用方式
# Out:
# 1.2246467991473532e-16

# %%
math.fabs(-4)   ## 注意此处返回值的类型
# Out:
# 4.0
